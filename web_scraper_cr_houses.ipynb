# %%
import os
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import regex as re
import requests 
import lxml

# %%
url = 'https://www.coldwellbankertamarindo.com/single-family-homes-for-sale'
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
response = response.content

# %%
soup = BeautifulSoup(response, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <title>Single Family Homes For Sale in Costa Rica | Coldwell Banker Tamarindo Realty</title>
# <meta content="Find your dream Single Family Homes For Sale in Costa Rica 's leading Estate Agency, Coldwell Banker Tamarindo Realty. View our range of houses, villas &amp; apartments for sale in Costa Rica today." name="description"/>
# <meta content="FIdx3pNkgGtCsiWFZOhOnQkq0FKzx46ZSlCWA3dy" name="csrf-token"/>
# <meta content="website" property="og:type"/>
# <meta content="Single Family Homes For Sale in Costa Rica | Coldwell Banker Tamarindo Realty" property="og:title"/>
# <meta content="Coldwell Banker Tamarindo Realty" property="og:site_name"/>
# <meta content="https://www.coldwellbankertamarindo.com/single-family-homes-for-sale" property="og:url"/>
# <meta content="en_GB" property="og:locale"/>
# ...

# %%
data = soup.find('div', {'class': 'f-14 c-lighter fix-line'}), soup.find('div', {'class': 'f-attr f-13 my-3'}),soup.find('div', {'class': 'f-price f-24 f-bold mb-3'})

# %%
data
# Out:
# (<div class="f-14 c-lighter fix-line">Tamarindo, Guanacaste</div>,
#  <div class="f-attr f-13 my-3"><span>07956 Listing ID </span> | <span>1 Bed </span> | <span>1 Bath</span> | <span>0.04 Acres</span></div>,
#  <div class="f-price f-24 f-bold mb-3">$85,000</div>)

# %%
loc = soup.find_all('div', {'class': 'f-14 c-lighter fix-line'})

# %%
data2 = soup.find_all('div', {'class': 'f-14 c-lighter fix-line'}), soup.find_all('div', {'class': 'f-attr f-13 my-3'}),soup.find_all('div', {'class': 'f-price f-24 f-bold mb-3'})

# %%
loc = soup.find_all('div', {'class': 'f-14 c-lighter fix-line'})

# %%
loc
# Out:
# [<div class="f-14 c-lighter fix-line">Tamarindo, Guanacaste</div>,
#  <div class="f-14 c-lighter fix-line">Tamarindo, Guanacaste</div>,
#  <div class="f-14 c-lighter fix-line">Tamarindo, Guanacaste</div>,
#  <div class="f-14 c-lighter fix-line">Monteverde, Puntarenas</div>,
#  <div class="f-14 c-lighter fix-line">Tamarindo, Guanacaste</div>,
#  <div class="f-14 c-lighter fix-line">Avellanas, Guanacaste</div>,
#  <div class="f-14 c-lighter fix-line">Tamarindo, Guanacaste</div>,
#  <div class="f-14 c-lighter fix-line">Playa Potrero, Guanacaste</div>,
#  <div class="f-14 c-lighter fix-line">Tamarindo, Guanacaste</div>,
#  <div class="f-14 c-lighter fix-line">Tamarindo, Guanacaste</div>,
#  <div class="f-14 c-lighter fix-line">Tamarindo, Guanacaste</div>,
#  <div class="f-14 c-lighter fix-line">Tamarindo, Guanacaste</div>,
#  <div class="f-14 c-lighter fix-line">Tamarindo, Guanacaste</div>,
#  <div class="f-14 c-lighter fix-line">Tamarindo, Guanacaste</div>,
# ...

# %%
LOC = pd.DataFrame(loc)

# %%
LOC
# Out:
#                             0
# 0       Tamarindo, Guanacaste
# 1       Tamarindo, Guanacaste
# 2       Tamarindo, Guanacaste
# 3      Monteverde, Puntarenas
# 4       Tamarindo, Guanacaste
# 5       Avellanas, Guanacaste
# 6       Tamarindo, Guanacaste
# 7   Playa Potrero, Guanacaste
# 8       Tamarindo, Guanacaste
# 9       Tamarindo, Guanacaste
# 10      Tamarindo, Guanacaste
# 11      Tamarindo, Guanacaste
# 12      Tamarindo, Guanacaste
# 13      Tamarindo, Guanacaste
# 14      Tamarindo, Guanacaste
# 15      Tamarindo, Guanacaste
# 16      Tamarindo, Guanacaste
# 17      Tamarindo, Guanacaste
# 18      Tamarindo, Guanacaste
# 19      Tamarindo, Guanacaste

# %%
bed = soup.find_all('div', {'class': 'f-attr f-13 my-3'})

# %%
bed
# Out:
# [<div class="f-attr f-13 my-3"><span>07956 Listing ID </span> | <span>1 Bed </span> | <span>1 Bath</span> | <span>0.04 Acres</span></div>,
#  <div class="f-attr f-13 my-3"><span>18022 Listing ID </span> | <span>1 Bed </span> | <span>1 Bath</span> | <span>0.05 Acres</span></div>,
#  <div class="f-attr f-13 my-3"><span>13659 Listing ID </span> | <span>3 Bed </span> | <span>2.5 Bath</span> | <span>0.05 Acres</span></div>,
#  <div class="f-attr f-13 my-3"><span>18263 Listing ID </span> | <span>3 Bed </span> | <span>3 Bath</span> | <span>0.05 Acres</span></div>,
#  <div class="f-attr f-13 my-3"><span>17311 Listing ID </span> | <span>3 Bed </span> | <span>3 Bath</span> | <span>0.08 Acres</span></div>,
#  <div class="f-attr f-13 my-3"><span>17590 Listing ID </span> | <span>2 Bed </span> | <span>2 Bath</span> | <span>1.26 Acres</span></div>,
#  <div class="f-attr f-13 my-3"><span>17865 Listing ID </span> | <span>2 Bed </span> | <span>2 Bath</span> | <span>0.1 Acres</span></div>,
# ...

# %%
BED = pd.DataFrame(bed)
# Out:
# C:\Users\detro\anaconda3\lib\site-packages\pandas\core\internals\construction.py:576: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   values = np.array([convert(v) for v in values])

# %%
BED
# Out:
#                                                     0
# 0   [[07956 Listing ID ],  | , [1 Bed ],  | , [1 B...
# 1   [[18022 Listing ID ],  | , [1 Bed ],  | , [1 B...
# 2   [[13659 Listing ID ],  | , [3 Bed ],  | , [2.5...
# 3   [[18263 Listing ID ],  | , [3 Bed ],  | , [3 B...
# 4   [[17311 Listing ID ],  | , [3 Bed ],  | , [3 B...
# 5   [[17590 Listing ID ],  | , [2 Bed ],  | , [2 B...
# 6   [[17865 Listing ID ],  | , [2 Bed ],  | , [2 B...
# 7   [[18328 Listing ID ],  | , [2 Bed ],  | , [2 B...
# 8   [[17428 Listing ID ],  | , [3 Bed ],  | , [2.5...
# 9   [[15358 Listing ID ],  | , [2 Bed ],  | , [2 B...
# 10  [[18347 Listing ID ],  | , [3 Bed ],  | , [2 B...
# 11  [[11523 Listing ID ],  | , [3 Bed ],  | , [3.5...
# 12  [[14485 Listing ID ],  | , [3 Bed ],  | , [3.5...
# 13  [[14226 Listing ID ],  | , [3 Bed ],  | , [2 B...
# 14  [[16480 Listing ID ],  | , [3 Bed ],  | , [2 B...
# 15  [[18207 Listing ID ],  | , [3 Bed ],  | , [2 B...
# ...

# %%
price = soup.find_all('div', {'class': 'f-price f-24 f-bold mb-3'})

# %%
price
# Out:
# [<div class="f-price f-24 f-bold mb-3">$85,000</div>,
#  <div class="f-price f-24 f-bold mb-3">$129,000</div>,
#  <div class="f-price f-24 f-bold mb-3">$135,000</div>,
#  <div class="f-price f-24 f-bold mb-3">$249,000</div>,
#  <div class="f-price f-24 f-bold mb-3">$250,000</div>,
#  <div class="f-price f-24 f-bold mb-3">$275,000</div>,
#  <div class="f-price f-24 f-bold mb-3">$279,000</div>,
#  <div class="f-price f-24 f-bold mb-3">$293,700</div>,
#  <div class="f-price f-24 f-bold mb-3">$389,000</div>,
#  <div class="f-price f-24 f-bold mb-3">$399,000</div>,
#  <div class="f-price f-24 f-bold mb-3">$429,000</div>,
#  <div class="f-price f-24 f-bold mb-3">$449,000</div>,
#  <div class="f-price f-24 f-bold mb-3">$450,000</div>,
#  <div class="f-price f-24 f-bold mb-3">$480,000</div>,
#  <div class="f-price f-24 f-bold mb-3">$495,000</div>,
#  <div class="f-price f-24 f-bold mb-3">$495,000</div>,
#  <div class="f-price f-24 f-bold mb-3">$499,000</div>,
# ...

# %%
PRICE = pd.DataFrame(price)

# %%
PRICE
# Out:
#            0
# 0    $85,000
# 1   $129,000
# 2   $135,000
# 3   $249,000
# 4   $250,000
# 5   $275,000
# 6   $279,000
# 7   $293,700
# 8   $389,000
# 9   $399,000
# 10  $429,000
# 11  $449,000
# 12  $450,000
# 13  $480,000
# 14  $495,000
# 15  $495,000
# 16  $499,000
# 17  $525,000
# 18  $529,900
# 19  $565,000

# %%
frames = [LOC, BED, PRICE]
page1 = pd.concat(frames)

# %%
page1 = LOC.join(BED)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3876\2881381763.py in <module>
# ----> 1 page1 = LOC.join(BED)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    9261         5  K1  A5   B1
#    9262         """
# -> 9263         return self._join_compat(
#    9264             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    9265         )
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    9292                     sort=sort,
#    9293                 )
# -> 9294             return merge(
#    9295                 self,
#    9296                 other,
#
# ...
